# %%
from pandas import *
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hubble =  read_csv("hubble_data.csv")  
hubble.head()
# Out:
#    distance  recession_velocity
# 0     0.032                 170
# 1     0.034                 290
# 2     0.214                -130
# 3     0.263                 -70
# 4     0.275                -185

# %%
hubble.describe()
# Out:
#         distance  recession_velocity
# count  24.000000           24.000000
# mean    0.911375          373.125000
# std     0.645496          371.254666
# min     0.032000         -220.000000
# 25%     0.406250          165.000000
# 50%     0.900000          295.000000
# 75%     1.175000          537.500000
# max     2.000000         1090.000000

# %%
hubble.columns = ['DISTANCE','VELOCITY']
hubble.set_index('DISTANCE',inplace=True)
hubble.head()
# Out:
#           VELOCITY
# DISTANCE
# 0.032          170
# 0.034          290
# 0.214         -130
# 0.263          -70
# 0.275         -185

# %%
hubble.plot()
plt.show()

# %%
hubble.sort_values(by=['DISTANCE'])
hubble
# Out:
#           VELOCITY
# DISTANCE
# 0.032          170
# 0.034          290
# 0.214         -130
# 0.263          -70
# 0.275         -185
# 0.275         -220
# 0.450          200
# 0.500          290
# 0.500          270
# 0.630          200
# 0.800          300
# 0.900          -30
# 0.900          650
# 0.900          150
# 0.900          500
# 1.000          920
# 1.100          450
# 1.100          500
# 1.400          500
# 1.700          960
# 2.000          500
# 2.000          850
# 2.000          800
# 2.000         1090
